# %% [markdown]
# # DIGIT PREPROCESSING

# %% [markdown]
# ## Imports

# %%
from PIL                import Image, ImageFilter
from IPython.display    import Image as show
import numpy as np
from IPython.display    import display
import picamera

# %% [markdown]
# ## Functions

# %%
def preview(img, title = ''):
    pix_path = '/tmp/pix_output.png'
    img.save(pix_path)
    pic = show(filename=pix_path)
    if title != '': print title
    display(pic)

# %%
def black_and_white(img, threshold = 128):
    gray = img.convert('L')        # convert the RGB image to grayscale image
    bw = np.asarray(gray).copy()   # read the grayscale image into an array

    bw[bw < threshold]  = 0        # Black
    bw[bw >= threshold] = 255      # White

    img = Image.fromarray(bw)
    return img

# %%
def resize(img, x, y, antialias = None):
    img.thumbnail((x, y), antialias) if antialias else img.thumbnail((x, y))
    return img

# %%
def gaussian_blur(img, radius):
    img = img.filter(ImageFilter.GaussianBlur(radius))
    return img

# %%
def sharpen(img):
    img.filter(ImageFilter.SHARPEN)
    return img

# %%
def print_ascii(img):
    arr = np.asarray(img).copy()
    print_array_dimensions(arr)
    for row in arr:
        line = ''
        for cell in row:
            result = 0
            if cell == 0:
                result = 1
            line = line + str(result)
        print line

# %%
def add_frame(img, border_width = 0, pad_with = 255):
    arr = np.asarray(img).copy()
    new_array = np.pad(arr, 4, mode='constant', constant_values=pad_with)
    
    img = Image.fromarray(new_array)
    return img

# %%
def print_array_dimensions(a):
    print "(%s, %s)" % (len(a), len(a[0]))

# %%
def crop_to_minimum(bw_image):
    img_array = np.asarray(bw_image).copy()
    img_array = img_array[~np.all(img_array == 255, axis=1)]
    img_array = img_array[:,~np.all(img_array == 255, axis=0)]
    cropped_image = Image.fromarray(img_array)
    return cropped_image

# %%
def process_cropped_digit(path_or_image):
    digit = path_or_image
    
    if(type(path_or_image) == type('')):
        digit = Image.open(input_digit)

    preview(digit, 'original')

    digit = black_and_white(digit, 144)
    preview(digit, 'b/w on original')

    digit = gaussian_blur(digit, 6)
    preview(digit, 'blurred')

    digit = sharpen(digit)
    preview(digit, 'sharpened')

    digit = black_and_white(digit, 192)
    preview(digit, 'bw on blurred/sharpened')

    digit = resize(digit, 20, 20)
    preview(digit, 'resized')

    digit = black_and_white(digit, 96)
    preview(digit, 'bw on blurred/sharpened/resized')

    print_ascii(digit)

    digit = add_frame(digit)
    preview(digit, 'with white frame of 4')

    print_ascii(digit)

# %% [markdown]
# ## Digit image paths

# %%
DIGITS_FOLDER = '/home/farmer/raspifarm/resources/images/digits'

digitPathFor = {
    "0": DIGITS_FOLDER + '/digit_0_64x64.jpg',
    "1": DIGITS_FOLDER + '/digit_1_64x64.jpg',
    "2": DIGITS_FOLDER + '/digit_2_64x64.jpg',
    "3": DIGITS_FOLDER + '/digit_3_64x64.jpg',
    "4": DIGITS_FOLDER + '/digit_4_64x64.jpg',
    "5": DIGITS_FOLDER + '/digit_5_64x64.jpg',
    "6": DIGITS_FOLDER + '/digit_6_64x64.jpg',
    "7": DIGITS_FOLDER + '/digit_7_64x64.jpg',
    "8": DIGITS_FOLDER + '/digit_8_64x64.jpg',
    "9": DIGITS_FOLDER + '/digit_9_64x64.jpg'
}

# %%
# Example, show a digit
show(digitPathFor['3'])

# %% [markdown]
# ## Preprocess a digit

# %%
process_cropped_digit(digitPathFor['2'])
# Out:
# original
# b/w on original
# blurred
# sharpened
# bw on blurred/sharpened
# resized
# bw on blurred/sharpened/resized
# (20, 20)
# 00000000111100000000
# 00000011111110000000
# 00000011111110000000
# 00000011101111000000
# 00000010000011000000
# 00000000000010000000
# 00000000000010000000
# 00000000000110000000
# 00000000000110000000
# 00000000001110000000
# 00000000011100000000
# 00000000111000000000
# 00000001111000000000
# 00000001110000000000
# 00000011100000000000
# 00000111100000000000
# 00001111100000000000
# 00011111111111111000
# 00011111111111111100
# 00011111111111111000
# with white frame of 4
# (28, 28)
# 0000000000000000000000000000
# 0000000000000000000000000000
# 0000000000000000000000000000
# 0000000000000000000000000000
# 0000000000001111000000000000
# 0000000000111111100000000000
# 0000000000111111100000000000
# 0000000000111011110000000000
# 0000000000100000110000000000
# 0000000000000000100000000000
# 0000000000000000100000000000
# 0000000000000001100000000000
# 0000000000000001100000000000
# 0000000000000011100000000000
# 0000000000000111000000000000
# 0000000000001110000000000000
# 0000000000011110000000000000
# 0000000000011100000000000000
# 0000000000111000000000000000
# 0000000001111000000000000000
# 0000000011111000000000000000
# 0000000111111111111110000000
# 0000000111111111111111000000
# 0000000111111111111110000000
# 0000000000000000000000000000
# 0000000000000000000000000000
# 0000000000000000000000000000
# 0000000000000000000000000000

# %% [markdown]
# # Take a picture from Picamera

# %%
def take_a_pic():
    picam_output_path = '/tmp/picam.jpg'
    
    with picamera.PiCamera() as camera:
        camera = picamera.PiCamera()
        camera.resolution = (512,512)
        camera.capture(picam_output)

    image = Image.open(camera_pic_path)
    return image

# %%
camera_pic = take_a_pic()
preview(camera_pic, 'Recorded image')
# Out:
# PiCameraMMALErrorTraceback (most recent call last)
# <ipython-input-16-63530ca46fd5> in <module>()
# ----> 1 camera_pic = take_a_pic()
#       2 preview(camera_pic, 'Recorded image')
#
# <ipython-input-14-cb43f7feac5d> in take_a_pic()
#       3
#       4     with picamera.PiCamera() as camera:
# ----> 5         camera = picamera.PiCamera()
#       6         camera.resolution = (512,512)
#       7         camera.capture(picam_output)
#
# /usr/lib/python2.7/dist-packages/picamera/camera.pyc in __init__(self, camera_num, stereo_mode, stereo_decimate, resolution, framerate, sensor_mode, led_pin, clock_mode)
#     415             self._init_camera(camera_num, stereo_mode, stereo_decimate)
#     416             self._configure_camera(sensor_mode, framerate, resolution, clock_mode)
# --> 417             self._init_preview()
#     418             self._init_splitter()
#     419             self._camera.enabled = True
#
# /usr/lib/python2.7/dist-packages/picamera/camera.pyc in _init_preview(self)
#     494         # fade to black (issue #22)
#     495         self._preview = PiNullSink(
# --> 496             self, self._camera.outputs[self.CAMERA_PREVIEW_PORT])
#     497
#     498     def _start_capture(self, port):
#
# /usr/lib/python2.7/dist-packages/picamera/renderers.pyc in __init__(self, parent, source)
#     510         self.renderer = mo.MMALNullSink()
#     511         self.renderer.enabled = True
# --> 512         self.renderer.connect(source)
#     513
#     514     def close(self):
#
# /usr/lib/python2.7/dist-packages/picamera/mmalobj.pyc in connect(self, source)
#    1463         if self.connection:
#    1464             self.disconnect()
# -> 1465         self._connection = MMALConnection(source, self.inputs[0])
#    1466
#    1467     def disconnect(self):
#
# /usr/lib/python2.7/dist-packages/picamera/mmalobj.pyc in __init__(self, source, target)
#    1276         mmal_check(
#    1277             mmal.mmal_connection_enable(self._connection),
# -> 1278             prefix="Failed to enable connection")
#    1279
#    1280     def close(self):
#
# /usr/lib/python2.7/dist-packages/picamera/exc.pyc in mmal_check(status, prefix)
#     155     """
#     156     if status != mmal.MMAL_SUCCESS:
# --> 157         raise PiCameraMMALError(status, prefix)
#     158
#
# PiCameraMMALError: Failed to enable connection: Out of resources (other than memory)

# %%
camera_pic = Image.open(camera_pic_path)

preview(camera_pic, 'Recorded image')

camera_pic = black_and_white(camera_pic, 76)
preview(camera_pic, 'Black and white image')

camera_pic = crop_to_minimum(camera_pic)
preview(camera_pic, 'Cropped image')
# Out:
# Recorded image
# Black and white image
# Cropped image
