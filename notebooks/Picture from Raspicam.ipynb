# %% [markdown]
# # Take a picture from RaspiCam

# %% [markdown]
# [https://www.raspberrypi.org/documentation/usage/camera/python/README.md]()

# %%
# setup 
from IPython.display import Image as show
import numpy as np
import time
import picamera

# %%
camera = picamera.PiCamera()

# configuration
camera.resolution = (512,512)

# %% [markdown]
# ## Take image

# %%
OUTPUT_DIR = '/home/farmer/Images/'

camera_pic_path  = OUTPUT_DIR + 'digit.jpg'
cropped_pic_path = OUTPUT_DIR + 'digit_2.jpg'

camera.capture(camera_pic_path)
camera.close()

# %%
camera.start_preview()
# Out:
# ---------------------------------------------------------------------------
# PiCameraClosed                            Traceback (most recent call last)
# <ipython-input-7-4e22aaf1ea27> in <module>()
# ----> 1 camera.start_preview()
#
# /usr/lib/python2.7/dist-packages/picamera/camera.pyc in start_preview(self, **options)
#     768             associated preview.
#     769         """
# --> 770         self._check_camera_open()
#     771         self._preview.close()
#     772         options.setdefault('layer', self._preview_layer)
#
# /usr/lib/python2.7/dist-packages/picamera/camera.pyc in _check_camera_open(self)
#     521             raise exc
#     522         if self.closed:
# --> 523             raise PiCameraClosed("Camera is closed")
#     524
#     525     def _check_recording_stopped(self):
#
# PiCameraClosed: Camera is closed

# %% [markdown]
# ## Display image

# %%
show(camera_pic_path)

# %% [markdown]
# ## Cropped image

# %%
Image(cropped_pic_path)

# %%
# from skimage.color.adapt_rgb import adapt_rgb, each_channel, hsv_value
# Out:
# ------------------------------------------------------------------------
# ImportError                            Traceback (most recent call last)
# <ipython-input-7-f998495ac6f8> in <module>()
# ----> 1 from skimage.color.adapt_rgb import adapt_rgb, each_channel, hsv_value
#
# ImportError: No module named adapt_rgb

# %%
from skimage import io

# %%
from PIL import Image, ImageFilter

# %%
image = Image.open("/home/farmer/Images/digit.jpg")
mask = image.convert("L")
th = 150 
mask = mask.point(lambda i: i < th and 255)
edges = image.filter(ImageFilter.FIND_EDGES)
edges.save("/home/farmer/Images/edges.jpg")

# %%
from IPython.display import Image as bla

# %%
bla("/home/farmer/Images/edges.jpg")
# bla("/home/farmer/Images/digit.jpg")
